# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Belin
# Hello Belin

# %% [markdown]
# Welcome to English Tenses! Hello I am Happy the Hippo. Today we are going to learn the English tenses in a fun and easy way. Have fun!☺️
# ![](Hippo-2.png)
#
# Let us start with the simple present.

# %% [markdown]
# <font color='blue'>The simple present is when you use a verb to tell about things that happen continually in the present, like every day, every week, or every month. Here is an example: I **go** to school every day.
#
# </font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the **simple present** into the space.

# %%
a=input("Are you ready?")
if a=='Yes':
    ans=input("1. I always _____ (watch) TV in the afternoon.")
    if ans=='watch':
        print("Correct!🥳")
    else:
        print("Incorrect.Try again!")
        ans=input("1. I always _____ (watch) TV in the afternoon.")
        if ans=='watch':
            print("Yay you made it!✅")
        else:
            print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatch " + "\33[m.")
# Out:
# Are you ready?Yes
# 1. I always _____ (watch) TV in the afternoon.watch
# Correct!🥳

# %%
ans=input("2. I _____ (learn) English vocabulary everyday.")
if ans=='learn':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary everyday.")
    if ans=='learn':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearn " + "\33[m.")
# Out:
# 2. I _____ (learn) English vocabulary everyday.learn
# Correct!🥳

# %% [markdown]
# <font color='green'>Yay, you learned your first English tense - the simple present! Let us continue with the present progressive.</font>
#
# ![](England-2.png)

# %% [markdown]
# <font color='blue'>The present progressive is used to describe an activity currently in progress. For example: I **am reading** right now.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the **present progressive** into the space.

# %%
ans=input("1. Now I _____ (watch) TV.")
if ans=='am watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. Now I _____ (watch) TV.")
    if ans=='am watching':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mam watching " + "\33[m.")
# Out:
# 1. Now I _____ (watch) TV.watch
# Incorrect.Try again!
# 1. Now I _____ (watch) TV.jfoef
# Incorrect. No worries, it will get better. The correct answer is am watching .

# %%
ans=input("2. At the moment I _____ (learn) English vocabulary.")
if ans=='am learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. At the moment I _____ (learn) English vocabulary.")
    if ans=='am learning':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mam learning " + "\33[m.")
# Out:
# 2. At the moment I _____ (learn) English vocabulary.fo
# Incorrect.Try again!
# 2. At the moment I _____ (learn) English vocabulary.ff
# Incorrect. No worries, it will get better. The correct answer is am learning .

# %% [markdown]
# <font color='green'>You learned the present progressive! Let us continue with the simple past.</font>

# %% [markdown]
# <font color='blue'>The simple past tense of regular verbs is marked by the ending -d or -ed. An example of a simple past tense verb used in a sentence would be: I played football at the park.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the **simple past** into the space.

# %%
ans=input("1. I _____ (watch) TV yesterday.")
if ans=='watched':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV yesterday.")
    if ans=='watched':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatched " + "\33[m.")
# Out:
# 1. I _____ (watch) TV yesterday.d
# Incorrect.Try again!
# 1. I _____ (watch) TV yesterday.d
# Incorrect. No worries, it will get better. The correct answer is watched .

# %%
ans=input("2. I _____ (learn) English vocabulary a week ago.")
if ans=='learned':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary a week ago.")
    if ans=='learned':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearned " + "\33[m.")
# Out:
# 2. I _____ (learn) English vocabulary a week ago.e
# Incorrect.Try again!
# 2. I _____ (learn) English vocabulary a week ago.e
# Incorrect. No worries, it will get better. The correct answer is learned .

# %% [markdown]
# <font color='green'>Yay,you learned the simple past! You are halfway there!
# ![](Yay-2.png)
#
# Let us continue with the past progressive.</font>

# %% [markdown]
# <font color='blue'>The past progressive tense refers to a continuing action or state that was happening at some point in the past. The past progressive tense is formed by combining the past tense of to be (i.e., was/were) with the verb's present participle (-ing word). For example: The sun was shining every day that summer.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the past progressive into the space.

# %%
ans=input("1. I _____ (watch) TV.")
if ans=='was watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV.")
    if ans=='was watching':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer \33[1mwas watching " + "\33[m.")
# Out:
# 1. I _____ (watch) TV.d
# Incorrect.Try again!
# 1. I _____ (watch) TV.f
# Incorrect. No worries, it will get better. The correct answer was watching .

# %%
ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
if ans=='was learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
    if ans=='was learning':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwas learning " + "\33[m.")
# Out:
# 2. While I _____ (learn) English vocabulary, my mom was cooking dinner.fr
# Incorrect.Try again!
# 2. While I _____ (learn) English vocabulary, my mom was cooking dinner.r
# Incorrect. No worries, it will get better. The correct answer is was learning .

# %% [markdown]
# <font color='green'>You learned the past progressive! Let us continue with the future.</font>

# %% [markdown]
# <font color='blue'>The will-future tense is a tense used for a future activity or a future state of being. To build the will-future you use will + infinitive. For example: The weather **will be** nice tomorrow.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the **will-future** into the space.

# %%
ans=input("1. I think the sun _____ (shine) tomorrow.")
if ans=='will shine':
        print("Correct!🥳")
else:
    print("Incorret.Try again!")
    ans=input("1. I think the sun _____ (shine) tomorrow.")
    if ans=='will shine':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwill shine " + "\33[m.")
# Out:
# 1. I think the sun _____ (shine) tomorrow.j
# Incorret.Try again!
# 1. I think the sun _____ (shine) tomorrow.
# Incorrect. No worries, it will get better. The correct answer is will shine .

# %%
ans=input("2. I hope our teacher _____ (not give) us homework today.")
if ans=='will not give':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I hope our teacher _____ (not give) us homework today.")
    if ans=='will not give':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwill not give " + "\33[m.")
# Out:
# 2. I hope our teacher _____ (not give) us homework today.
# Incorrect.Try again!
# 2. I hope our teacher _____ (not give) us homework today.l
# Incorrect. No worries, it will get better. The correct answer is will not give .

# %% [markdown]
# <font color='green'>You learned the will-future! Let us continue with the going-to-future.</font>

# %% [markdown]
# <font color='blue'>The going-to-future gives expression to an action that somebody intends/is going to do in the future (planned). To build the going-to-future you use am,is,are + going to + infinitive. For example: He **is going to apply** for a job in a big firm next week.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the going-to-future into the space.

# %%
ans=input("1. We _____ (play) football tomorrow.")
if ans=='are going to play':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. We _____ (play) football tomorrow.")
    if ans=='are going to play':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mare going to play " + "\33[m.")
# Out:
# 1. We _____ (play) football tomorrow.f
# Incorrect.Try again!
# 1. We _____ (play) football tomorrow.r
# Incorrect. No worries, it will get better. The correct answer is are going to play .

# %%
ans=input("2. Paul _____ (eat) chocolate cake today.")
if ans=='is going to eat':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. Paul _____ (eat) chocolate cake today.")
    if ans=='is going to eat':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mis going to eat " + "\33[m.")
# Out:
# 2. Paul _____ (eat) chocolate cake today.r#
# Incorrect.Try again!
# 1. Paul _____ (eat) chocolate cake today.r
# Incorrect. No worries, it will get better. The correct answer is is going to eat .

# %% [markdown]
# <font color='green'>Hurray! You learned all the English tenses!</font>
# ![](Goodjob-2.png)
#
# <font color='purple'>Let us play another round. Now you have the chance to prove what a good learner you are!</font>
#
# **Ready,steady,go!!!**

# %%
#List 
List = ["every day","last week","last year","last month","right now","yesterday","today","now","this year","in 1990","while","I think Marie will arrive in Stuttgart at 10 am.","I will go to school.","I will buy a new car.","Wait, I am going to help you.","It is going to rrain tomorrow.","We are going to play football at the birthday party.","The will-future is about future plans. The going-to-future is always about spontaneous decisions and actions you can not control.","The will-future is about spontaneous decisions and actions you can not control. The going-to-future is always about future plans.","You can use both whenever you want.","When actions are common or happen repeatedly.","When the action finished in the past.","When you plan an action for the future.","When something might happen in the future.","When you just finished with something.","When something is happening right now.","When you started something in the past and did not finish yet.","When the action finished in the past.","When the situation you are talking about happens right now.","When you plan something for the future.","When the action happened in the middle of another action.","When the action finished 10 years ago."]

class Score():
    s = 0
score = 0

def scoreup():
    Score.s = Score.s + 1
def scoredown():
    Score.s = Score.s - 1

# %%
#Question 1
print ("What is a signal word for the simple present?")

print ("a" + " " + str(List[0]))
print ("b" + " " + str(List[1]))
print ("c" + " " + str(List[2]))

answer1 = input("What is your answer?" + " ")


if answer1 == "a":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 2
print ("What is a signal word for the present progressive?")
print ("a" + " " + str(List[3]))
print ("b" + " " + str(List[4]))
print ("c" + " " + str(List[5]))

answer2 = input("What is your answer?" + " ")

if answer2 == "b":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 3
print ("What is a signal word for the simple past?")
print ("a" + " " + str(List[6]))
print ("b" + " " + str(List[5]))
print ("c" + " " + str(List[7]))

answer3 = input("What is your answer?" + " ")

if answer3 == "b":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 4
print ("What is a signal word for the past progressive?")
print ("a" + " " + str(List[8]))
print ("b" + " " + str(List[9]))
print ("c" + " " + str(List[10]))

answer4 = input("What is your answer?" + " ")

if answer4 == "c":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 5
print ("Which of these sentences is in the will-future?")
print ("a" + " " + str(List[11]))
print ("b" + " " + str(List[12]))
print ("c" + " " + str(List[13]))

answer5 = input("What is your answer?" + " ")

if answer5 == "a":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 6
print ("What is a signal for the going-to-future?")
print ("a" + " " + str(List[14]))
print ("b" + " " + str(List[15]))
print ("c" + " " + str(List[16]))

answer6 = input("What is your answer?" + " ")

if answer6 == "c":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 7
print ("What is the difference between the will and going-to future tenses?")
print ("a" + " " + str(List[17]))
print ("b" + " " + str(List[18]))
print ("c" + " " + str(List[19]))

answer7 = input("What is your answer?" + " ")

if answer7 == "b":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 8
print ("When do you use the simple present?")
print ("a" + " " + str(List[20]))
print ("b" + " " + str(List[21]))
print ("c" + " " + str(List[22]))

answer8 = input("What is your answer?" + " ")

if answer8 == "a":
    print("That is correct!")
    scorehoch()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 9
print ("When do you use the present progressive?")
print ("a" + " " + str(List[23]))
print ("b" + " " + str(List[24]))
print ("c" + " " + str(List[25]))

answer9 = input("What is your answer?" + " ")

if answer9 == "c":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))

# %%
#Question 10
print ("When do you use the simple past?")
print ("a" + " " + str(List[26]))
print ("b" + " " + str(List[27]))
print ("c" + " " + str(List[28]))

answer10 = input("What is your answer?" + " ")

if answer10 == "b":
    print("That is correct!")
    scoreup()
    print("Your score is" + " " + str(Score.s))
    
else:
     
    print("Sorry, that is wrong. ")
    scoredown()
    print("Your score is" + " " + str(Score.s))
.
