# %%
name = input("Enter your name: ")
print("Hello", name)

# %% [markdown]
# ## Welcome to English Tenses! Hello I am Happy the Hippo.

# %% [markdown]
#  ![](Hippo-2.png)

# %% [markdown]
# Today we are going to learn the English tenses in a fun and easy way. Have fun!☺️

# %% [markdown]
# Let us start with the simple present.

# %% [markdown]
# ### <font color='blue'>The simple present is when you use a verb to tell about things that happen continually in the present, like every day, every week, or every month. Here is an example: I **go** to school every day.
#
# </font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the **simple present** into the space.

# %% [markdown]
# # Tenses game

# %%
a=input("Are you ready?")
if a=='Yes':
    ans=input("1. I always _____ (watch) TV in the afternoon.")
    if ans=='watch':
        print("Correct!🥳")
    else:
        print("Incorrect.Try again!")
        ans=input("1. I always _____ (watch) TV in the afternoon.")
        if ans=='watch':
            print("Yay you made it!✅")
        else:
            print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatch " + "\33[m.")


ans=input("2. I _____ (learn) English vocabulary everyday.")
if ans=='learn':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary everyday.")
    if ans=='learn':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearn " + "\33[m.")

# %% [markdown]
# <font color='green'>Yay, you learned your first English tense - the simple present! Let us continue with the present progressive.</font>
#
# ![](England-2.png)

# %% [markdown]
# ### <font color='blue'>The present progressive is used to describe an activity currently in progress. For example: I **am reading** right now.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the present progressive into the space.

# %%
ans=input("1. Now I _____ (watch) TV.")
if ans=='am watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. Now I _____ (watch) TV.")
    if ans=='am watching':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mam watching " + "\33[m.")

        
        
ans=input("2. At the moment I _____ (learn) English vocabulary.")
if ans=='am learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. At the moment I _____ (learn) English vocabulary.")
    if ans=='am learning':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mam learning " + "\33[m.")

# %% [markdown]
# <font color='green'>You learned the present progressive! Let us continue with the simple past.</font>

# %% [markdown]
# ### <font color='blue'>The simple past tense of regular verbs is marked by the ending -d or -ed. An example of a simple past tense verb used in a sentence would be: I played football at the park.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the simple past into the space.

# %%
ans=input("1. I _____ (watch) TV yesterday.")
if ans=='watched':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV yesterday.")
    if ans=='watched':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatched " + "\33[m.")


        
ans=input("2. I _____ (learn) English vocabulary a week ago.")
if ans=='learned':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary a week ago.")
    if ans=='learned':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearned " + "\33[m.")

# %% [markdown]
# <font color='green'>Yay,you learned the simple past!

# %% [markdown]
# ## You are halfway there!

# %% [markdown]
# ![](Yay-2.png)
#
# Let us continue with the past progressive.</font>

# %% [markdown]
# ### <font color='blue'>The past progressive tense refers to a continuing action or state that was happening at some point in the past. The past progressive tense is formed by combining the past tense of to be (i.e., was/were) with the verb's present participle (-ing word). For example: The sun was shining every day that summer.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the past progressive into the space.

# %%
ans=input("1. I _____ (watch) TV.")
if ans=='was watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV.")
    if ans=='was watching':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer \33[1mwas watching " + "\33[m.")

        

ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
if ans=='was learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
    if ans=='was learning':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwas learning " + "\33[m.")

# %% [markdown]
# <font color='green'>You learned the past progressive! Let us continue with the future.</font>

# %% [markdown]
# ### <font color='blue'>The will-future tense is a tense used for a future activity or a future state of being. To build the will-future you use will + infinitive. For example: The weather **will be** nice tomorrow.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the will-future into the space.

# %%
ans=input("1. I think the sun _____ (shine) tomorrow.")
if ans=='will shine':
        print("Correct!🥳")
else:
    print("Incorret.Try again!")
    ans=input("1. I think the sun _____ (shine) tomorrow.")
    if ans=='will shine':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwill shine " + "\33[m.")

        
ans=input("2. I hope our teacher _____ (not give) us homework today.")
if ans=='will not give':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I hope our teacher _____ (not give) us homework today.")
    if ans=='will not give':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwill not give " + "\33[m.")

# %% [markdown]
# <font color='green'>You learned the will-future! Let us continue with the going-to-future.</font>

# %% [markdown]
# ### <font color='blue'>The going-to-future gives expression to an action that somebody intends/is going to do in the future (planned). To build the going-to-future you use am,is,are + going to + infinitive. For example: He **is going to apply** for a job in a big firm next week.</font>

# %% [markdown]
# Now it is your turn. Write the correct verb in the going-to-future into the space.

# %%
ans=input("1. We _____ (play) football tomorrow.")
if ans=='are going to play':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. We _____ (play) football tomorrow.")
    if ans=='are going to play':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mare going to play " + "\33[m.")
        

        
ans=input("2. Paul _____ (eat) chocolate cake today.")
if ans=='is going to eat':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. Paul _____ (eat) chocolate cake today.")
    if ans=='is going to eat':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mis going to eat " + "\33[m.")

# %% [markdown]
# # <font color='green'>Hurray! You learned all the English tenses!</font>

# %% [markdown]
# ![](Goodjob-2.png)
#
# <font color='purple'>Let us play another round. Now you have the chance to prove what a good learner you are!</font>

# %% [markdown]
# ## Ready,steady,go!!!

# %% [markdown]
# ### Multiple choice quiz

# %%
# List
List = ["every day", "last week", "last year", "last month", "right now", "yesterday", "today", "yesterday", "now", "this year", "in 1990", "while", "I think Marie will arrive in Stuttgart at 10 am.", "I am going to go to school.", "I buy a new car.", "Wait, I will help you.", "It is raining right now.","We are going to play football at the birthday party.", "The will-future is about future plans. The going-to-future is always about spontaneous decisions and actions you can not control.","The will-future is about spontaneous decisions and actions you can not control. The going-to-future is always about future plans.","You can use both whenever you want.","When actions are common or happen repeatedly.","When the action finished in the past.", "When you plan an action for the future.","When something might happen in the future.","When you just finished with something.", "When something is happening right now.","When you started something in the past and did not finish yet.","When the action finished in the past.","When the situation you are talking about happens right now.","When you plan something for the future.","When the action happened in the middle of another action.", "When the action finished 10 years ago.", "in 1990", "while", "I think Marie will arrive in Stuttgart at 10 am.", "I will go to school.", "I will buy a new car.", "Wait, I am going to help you.", "It is going to rain tomorrow.", "We are going to play football at the birthday party.", "The will-future is about future plans. The going-to-future is always about spontaneous decisions and actions you can not control.", "The will-future is about spontaneous decisions and actions you can not control. The going-to-future is always about future plans.", "You can use both whenever you want.", "When actions are common or happen repeatedly.", "When the action finished in the past.", "When you plan an action for the future.","When something might happen in the future.", "When you just finished with something.","When something is happening right now.", "When you started something in the past and did not finish yet.","When the action finished in the past.", "When the situation you are talking about happens right now.", "When you plan something for the future.", "When the action happened in the middle of another action.","When the action finished 10 years ago."]
questions = ["What is a signal word for the simple present?",
             "What is a signal word for the present progressive?",
             "What is a signal word for the simple past?",
             "What is a signal word for the past progressive?",
             "Which of these sentences is in the will-future?",
             "Which of these sentences is in the going-to-future?",
             "What is the difference between the will and going-to future tenses?",
             "When do you use the simple present?",
             "When do you use the present progressive?",
             "When do you use the simple past?"
             ]
options = ["a", "b", "c"]
correct = ["a", "b", "b", "c", "a", "c", "b", "a", "c", "b"]


class Score():
    s = 0

def scoreup():
    Score.s = Score.s + 1


def scoredown():
    Score.s = Score.s - 1


def resetscore():
    Score.s = 0


# Questions
while True:
    i = 0
    for q in questions:
        print(q)
        for ans in range(3):
            print(str(options[ans]) + " " + str(List[i]))
            i += 1
        answer = input("What is your answer?" + " ")
        if answer == correct[questions.index(q)]:
            print("That is correct!")
            scoreup()
            print("\33[1mYour score is" + " " + str(Score.s) + "\33[m.")
        else:
            print("Sorry, that is wrong. ")
            scoredown()
            print("\33[1mYour score is" + " " + str(Score.s) + "\33[m.")
            if Score.s <= -2:
                print("You have to start again!")
                break
    if Score.s == -2:
        resetscore()
    else:
        print("\33[1mGood Gob! You are finished! Your final score is " + str(Score.s) + "\33[m.")
        break
# Out:
# What is a signal word for the simple present?
# a every day
# b last week
# c last year
# What is your answer? a
# That is correct!
# Your score is 1.
# What is a signal word for the present progressive?
# a last month
# b right now
# c yesterday
# What is your answer? b
# That is correct!
# Your score is 2.
# What is a signal word for the simple past?
# a today
# b yesterday
# c now
# What is your answer? b
# That is correct!
# Your score is 3.
# What is a signal word for the past progressive?
# a this year
# b in 1990
# c while
# What is your answer? c
# That is correct!
# Your score is 4.
# Which of these sentences is in the will-future?
# a I think Marie will arrive in Stuttgart at 10 am.
# b I am going to go to school.
# c I buy a new car.
# What is your answer? a
# That is correct!
# Your score is 5.
# Which of these sentences is in the going-to-future?
# a Wait, I will help you.
# b It is raining right now.
# c We are going to play football at the birthday party.
# ...

# %% [markdown]
# # <font color='purple'>**Congratulations! You are done and learned all the tenses!!**</font>

# %% [markdown]
# ![](Kidscheering-2.png)

# %% [markdown]
# # Feedback

# %%
from IPython.display import Image
a = input("Did you like the quiz? (Yes/No)")
if a == 'Yes':
    print("We are happy to hear that!🥳")
    display (Image(url='https://image.freepik.com/free-vector/cartoon-happy-hippo-posing-grass_29190-5652.jpg', width=200, height=200))
if a == 'No':
    print("We are sorry to hear that. Hopefully you will like it better next time!🥺")
    display (Image(url='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQldnc2hD1Xe9vXMzp41v7MSUAPdXoEVzZTWTzps2WNpVBAkUxy2OKdYNY8_5C27KIHixc&usqp=CAU', width=200, height=200))
# Out:
# Did you like the quiz? (Yes/No)Yes
# We are happy to hear that!🥳
# <img src="https://image.freepik.com/free-vector/cartoon-happy-hippo-posing-grass_29190-5652.jpg" width="200" height="200"/>

# %% [markdown]
# <font color='green'>**Thank you for your feedback. I hope you had a great time! Enjoy your day and be happy!🌞**</font>
#
# ![](Hippo-2.png)
